# %%
import pandas as pd

# %%
df = pd.read_csv("supermarket_sales - Sheet1.csv")

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.groupby("City").Quantity.sum()
# Out:
# City
# Mandalay     1820
# Naypyitaw    1831
# Yangon       1859
# Name: Quantity, dtype: int64

# %%
df.coluns()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-7e94afe5c333> in <module>
# ----> 1 df.coluns()
#
# /usr/lib/python3/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'coluns'

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df.City
# Out:
# 0         Yangon
# 1      Naypyitaw
# 2         Yangon
# 3         Yangon
# 4         Yangon
# 5      Naypyitaw
# 6         Yangon
# 7      Naypyitaw
# 8         Yangon
# 9       Mandalay
# 10      Mandalay
# 11      Mandalay
# 12        Yangon
# 13        Yangon
# 14        Yangon
# 15      Mandalay
# 16        Yangon
# 17        Yangon
# 18        Yangon
# 19      Mandalay
# 20     Naypyitaw
# 21      Mandalay
# 22      Mandalay
# 23        Yangon
# 24        Yangon
# 25        Yangon
# 26      Mandalay
# 27        Yangon
# 28      Mandalay
# 29        Yangon
#          ...
# 970     Mandalay
# 971     Mandalay
# 972     Mandalay
# 973       Yangon
# 974    Naypyitaw
# 975     Mandalay
# 976       Yangon
# 977     Mandalay
# 978     Mandalay
# 979     Mandalay
# 980    Naypyitaw
# 981       Yangon
# 982       Yangon
# 983    Naypyitaw
# 984    Naypyitaw
# 985     Mandalay
# 986     Mandalay
# 987     Mandalay
# 988    Naypyitaw
# 989     Mandalay
# 990       Yangon
# ...

# %%
citys = df.City

# %%
citys.head(10)
# Out:
# 0       Yangon
# 1    Naypyitaw
# 2       Yangon
# 3       Yangon
# 4       Yangon
# 5    Naypyitaw
# 6       Yangon
# 7    Naypyitaw
# 8       Yangon
# 9     Mandalay
# Name: City, dtype: object

# %%
citys.sum()
# Out:
# '...'

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
df["Total"].sum()
# Out:
# 322966.74899999995

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
Yagon = df.loc[df["City"] == "Yangon"]

# %%
Yagon.head()
# Out:
#     Invoice ID Branch    City Customer type  Gender            Product line  \
# 0  750-67-8428      A  Yangon        Member  Female       Health and beauty
# 2  631-41-3108      A  Yangon        Normal    Male      Home and lifestyle
# 3  123-19-1176      A  Yangon        Member    Male       Health and beauty
# 4  373-73-7910      A  Yangon        Normal    Male       Sports and travel
# 6  355-53-5943      A  Yangon        Member  Female  Electronic accessories
#
#    Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 0       74.69         7  26.1415  548.9715   1/5/2019  13:08      Ewallet
# 2       46.33         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3       58.22         8  23.2880  489.0480  1/27/2019  20:33      Ewallet
# 4       86.31         7  30.2085  634.3785   2/8/2019  10:37      Ewallet
# 6       68.84         6  20.6520  433.6920  2/25/2019  14:36      Ewallet
#
#      cogs  gross margin percentage  gross income  Rating
# ...

# %%
len(Yagon)
# Out:
# 340

# %%
Yagon.shape
# Out:
# (340, 17)

# %%
data = df.loc[df["Date"] == "2/25/2019"].loc[data["City"] == "Mandalay"]
data.head()
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-47-ac7f50f24a8f> in <module>
# ----> 1 data = df.loc[df["Date"] == "2/25/2019"].loc[data["City"] == "Mandalay"]
#       2 data.head()
#
# /usr/lib/python3/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1310             return self._getitem_tuple(key)
#    1311         else:
# -> 1312             return self._getitem_axis(key, axis=0)
#    1313
#    1314     def _getitem_axis(self, key, axis=0):
#
# /usr/lib/python3/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1453             return self._get_slice_axis(key, axis=axis)
#    1454         elif is_bool_indexer(key):
# -> 1455             return self._getbool_axis(key, axis=axis)
#    1456         elif is_list_like_indexer(key):
#    1457
#
# ...

# %%
dataMand = data.loc[data["City"] == "Mandalay"]
dataMand.head()
# Out:
#       Invoice ID Branch      City Customer type  Gender         Product line  \
# 30   871-79-8483      B  Mandalay        Normal    Male  Fashion accessories
# 165  505-02-0892      B  Mandalay        Member    Male    Health and beauty
# 504  511-54-3087      B  Mandalay        Normal    Male    Sports and travel
# 570  834-83-1826      B  Mandalay        Member  Female   Home and lifestyle
# 831  636-17-0325      B  Mandalay        Normal    Male    Health and beauty
#
#      Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 30        94.13         5  23.5325  494.1825  2/25/2019  19:39  Credit card
# 165       42.57         8  17.0280  357.5880  2/25/2019  14:12      Ewallet
# 504       88.45         1   4.4225   92.8725  2/25/2019  16:36  Credit card
# 570       82.04         5  20.5100  430.7100  2/25/2019  17:16  Credit card
# 831       62.57         4  12.5140  262.7940  2/25/2019  18:37         Cash
#
# ...

# %%
dataMand.shape
# Out:
# (8, 17)

# %%
dataMand
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 30   871-79-8483      B  Mandalay        Normal    Male
# 165  505-02-0892      B  Mandalay        Member    Male
# 504  511-54-3087      B  Mandalay        Normal    Male
# 570  834-83-1826      B  Mandalay        Member  Female
# 831  636-17-0325      B  Mandalay        Normal    Male
# 853  866-70-2814      B  Mandalay        Normal  Female
# 877  608-05-3804      B  Mandalay        Member    Male
# 952  574-80-1489      B  Mandalay        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 30      Fashion accessories       94.13         5  23.5325  494.1825
# 165       Health and beauty       42.57         8  17.0280  357.5880
# 504       Sports and travel       88.45         1   4.4225   92.8725
# 570      Home and lifestyle       82.04         5  20.5100  430.7100
# 831       Health and beauty       62.57         4  12.5140  262.7940
# ...

# %%
df.loc[df["Customer type"] == "Normal"]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 12   365-64-0515      A     Yangon        Normal  Female
# 13   252-56-2699      A     Yangon        Normal    Male
# 14   829-34-3910      A     Yangon        Normal  Female
# 17   765-26-6951      A     Yangon        Normal    Male
# 18   329-62-1586      A     Yangon        Normal    Male
# 19   319-50-3348      B   Mandalay        Normal  Female
# 21   371-85-5789      B   Mandalay        Normal    Male
# 22   273-16-6619      B   Mandalay        Normal    Male
# 23   636-48-8204      A     Yangon        Normal    Male
# 26   649-29-6775      B   Mandalay        Normal    Male
# ...

# %%
df.groupby("Product line")["Payment"].nunique()
# Out:
# Product line
# Electronic accessories    3
# Fashion accessories       3
# Food and beverages        3
# Health and beauty         3
# Home and lifestyle        3
# Sports and travel         3
# Name: Payment, dtype: int64

# %% [raw]
# df.groupby("")

# %%
df.groupby("Product line")["Gender"].nunique()
# Out:
# Product line
# Electronic accessories    2
# Fashion accessories       2
# Food and beverages        2
# Health and beauty         2
# Home and lifestyle        2
# Sports and travel         2
# Name: Gender, dtype: int64

# %%
Eletronics = df.loc[df["Product line"] == "Electronic accessories"]
Eletronics.loc[Eletronics["Gender"] == "Male"].shape
# Out:
# (86, 17)

# %%
Eletronics.loc[Eletronics["Gender"] == "Female"].shape
# Out:
# (84, 17)

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
listaGenero = ['Male', 'Female']

for i in listaGenero:
    print('Genero: {}, Quantidade= {}'.format(i, df.loc[df["Gender"] == i].shape))
# Out:
# Genero: Male, Quantidade= (499, 17)
# Genero: Female, Quantidade= (501, 17)

# %%
df["Gender"].nunique()
# Out:
# 2

# %%
df.groupby("Gender")["Quantity"].nunique()
# Out:
# Gender
# Female    10
# Male      10
# Name: Quantity, dtype: int64
